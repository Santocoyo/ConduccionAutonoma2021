# %%
# Librería para cargar nuestro drive
from google.colab import drive
# Cargamos nuestro drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/My Drive/Conducción Automática 2021/SDC1"
# Out:
# Colab_Alejandro_Santoscoy.ipynb  datos	figuras

# %% [markdown]
# # Ejemplo de notebook Jupyter

# %% [markdown]
# ## 1. Cargar los datos

# %% [markdown]
# Importando las librerías de matplotlib y pandas

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# En este momento se utilizará la gráfica de la cronología de los precios de los teléfonos móviles a lo largo de los años
# *Fuente:* https://www.ooma.com/home-phone/cell-phone-cost-comparison/
#
# ![Imagen de costos de celular](https://docs.google.com/uc?export=download&id=1aH-L6iWgi3go8sLgRmbxr24cC8pMjui3)

# %% [markdown]
# Leer datos del archivo datos.csv

# %%
data = pd.read_csv("/content/drive/My Drive/Conducción Automática 2021/SDC1/datos/datos.csv")

# %% [markdown]
# Vista previa de las primera 5 líneas de los datos cargados

# %%
print(data.head())
# Out:
#    dia  casos
# 0    1   8642
# 1    2   8462
# 2    3   7512
# 3    4   7246
# 4    5   2810

# %% [markdown]
# ## 2. Graficar los datos

# %% [markdown]
# Graficamos las variables

# %%
data.plot(x ='dia', y="casos", kind="line")
plt.show()
