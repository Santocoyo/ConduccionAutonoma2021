# %% [markdown]
# # Ejemplo de notebook de Jupyter

# %% [markdown]
# ## 1. Cargar los datos

# %% [markdown]
# Importando las librerías matplotlib y pandas

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### Mostrando información usando Markdown

# %% [markdown]
# En este momento se utilizará la gráfica de la cronología de los precios de los teléfonos móviles a lo largo de los años
# *Fuente:* https://www.ooma.com/home-phone/cell-phone-cost-comparison/
# ![Imagen de costos de celular](figuras/img_cell_phone_cost.png)

# %% [markdown]
# ### Mostrando la misma información usando HTML

# %% [markdown]
# En este momento se utilizará la gráfica de la cronología de los precios de los teléfonos móviles a lo largo de los años
# *Fuente:* https://www.ooma.com/home-phone/cell-phone-cost-comparison/
# <img src="figuras/img_cell_phone_cost.png" width=150>

# %% [markdown]
# Leyendo datos del archivos datos.csv

# %%
data = pd.read_csv('datos/datos.csv')

# %% [markdown]
# Mostrando la vista previa de las primeras 5 líneas

# %%
print(data.head())
# Out:
#    dia  casos
# 0    1   8642
# 1    2   8462
# 2    3   7512
# 3    4   7246
# 4    5   2810

# %% [markdown]
# ## 2. Graficar los datos

# %% [markdown]
# Graficamos las variables, en este caso se están graficando los nuevos casos de COVID-19 en México durante las últimas 2 semanas (10 de marzo de 2021)

# %%
data.plot(x = 'dia', y='casos', kind='line')
plt.show()
